# %%
import yt
import numpy as np
import matplotlib.pyplot as plt

# %%
binned=np.load("impact_par_selection/impact_param.npy")
binned.shape
# Out:
# (10,)

# %%
y=binned[9]
y.shape
# Out:
# (19,)

# %%
y
# Out:
# array([0.16598944383163733 code_length, 0.1803897232946592 code_length,
#        0.16871861171414926 code_length, 0.17159597499694157 code_length,
#        0.17847986769178778 code_length, 0.16808064508430595 code_length,
#        0.16808757385384837 code_length, 0.17960794062731913 code_length,
#        0.17447602240247528 code_length, 0.16860248480461432 code_length,
#        0.17466024019090426 code_length, 0.17077036028848314 code_length,
#        0.17296348879780732 code_length, 0.17254190289206794 code_length,
#        0.1829079608492235 code_length, 0.1808402989726566 code_length,
#        0.16945313872954998 code_length, 0.1789953717986621 code_length,
#        0.1831048427674237 code_length], dtype=object)

# %%
impact_param=[]

for lis in binned:
    for j in lis:
        impact_param.append(j)

# %%
len(impact_param)
# Out:
# 125

# %%
for i in range(len(impact_param)):
    impact_param[i] = impact_param[i].in_units('kpc')

# %%
impact_param[0]
# Out:
# 29.218889973896236 kpc

# %%
plt.hist(impact_param, bins=25)
plt.title("impact param hist")
plt.xlabel("impact param in kpc")
# Out:
# Text(0.5,0,'impact param in kpc')

# %%
for ip in binned:
    plt.plot(ip)
