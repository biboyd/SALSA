# %% [markdown]
# # Example Guide to using SALSA to extract absorbers from a dataset

# %% [markdown]
# First we need to download a dataset to work with. Here we'll use a yt test dataset of an Isolated Galaxy Simulation

# %%
import yt
import salsa
import numpy as np
from astropy.units import kpc

# %%
# Download one of yt's sample datasets
# Requires the "pooch" package
ds = yt.load_sample("IsolatedGalaxy")

raydir = './'

nrays = 2

ion_list = ['H I', 'C IV']  # A list of ions for which to look for absorbers

center=[0.5, 0.5, 0.5],  # Center from which to measure impact paramter, in code units
impact_range = [0, 50]  # Range of impact parameters. Defaults to kpc if nothing is specified.
ray_length = 200 * kpc  # Units can be specified with astropy or unyt.

add_fields = ['temperature', 'metallicity']  # Additional fields to extract & save in the dataset
field_units = {'metallicity':'Zsun'}  # Units to convert those additional fields to

np.random.seed(567)
tab = salsa.generate_catalog(ds, nrays, raydir, ion_list,
                             method='spice',  # currently the only supported method
                             center = center,
                             impact_param_lims = impact_range,
                             ray_length = ray_length,
                             fields = add_fields,
                             extractor_kwargs={'velocity_res':25, 'absorber_min':12.8, 'frac':0.8},)
                             #units_dict = field_units)
# Out:
# /home/claire/miniforge3/envs/salsa-env/lib/python3.13/site-packages/yt/sample_data/api.py:150: UserWarning: Storage directory from yt config doesn't exist (currently set to 'tests/data'). Current working directory will be used instead.
#   warn(
# yt : [INFO     ] 2025-08-12 16:09:26,647 Sample dataset found in '/home/claire/research/SALSA/notebooks/IsolatedGalaxy/galaxy0030/galaxy0030'
# yt : [INFO     ] 2025-08-12 16:09:26,759 Parameters: current_time              = 0.0060000200028298
# yt : [INFO     ] 2025-08-12 16:09:26,759 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-08-12 16:09:26,760 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-08-12 16:09:26,760 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-08-12 16:09:26,761 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2025-08-12 16:09:26,828 Parameters: current_time              = 0.0060000200028298 code_time
# yt : [INFO     ] 2025-08-12 16:09:26,829 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-08-12 16:09:26,829 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2025-08-12 16:09:26,830 Parameters: domain_right_edge         = [1. 1. 1.] code_length
# yt : [INFO     ] 2025-08-12 16:09:26,830 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2025-08-12 16:09:26,887 Allocating for 249 particles
# yt : [INFO     ] 2025-08-12 16:09:27,099 Parameters: current_time              = 0.0060000200028298 code_time
# yt : [INFO     ] 2025-08-12 16:09:27,099 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-08-12 16:09:27,099 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2025-08-12 16:09:27,100 Parameters: domain_right_edge         = [1. 1. 1.] code_length
# yt : [INFO     ] 2025-08-12 16:09:27,100 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2025-08-12 16:09:27,159 Allocating for 180 particles
# yt : [INFO     ] 2025-08-12 16:09:27,340 Parameters: current_time              = 0.0060000200028298 code_time
# yt : [INFO     ] 2025-08-12 16:09:27,341 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-08-12 16:09:27,341 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2025-08-12 16:09:27,342 Parameters: domain_right_edge         = [1. 1. 1.] code_length
# yt : [INFO     ] 2025-08-12 16:09:27,342 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2025-08-12 16:09:27,400 Allocating for 249 particles
# /home/claire/miniforge3/envs/salsa-env/lib/python3.13/site-packages/unyt/array.py:1972: RuntimeWarning: invalid value encountered in divide
#   out_arr = func(
# yt : [INFO     ] 2025-08-12 16:09:28,234 Parameters: current_time              = 0.0060000200028298 code_time
# yt : [INFO     ] 2025-08-12 16:09:28,235 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-08-12 16:09:28,235 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2025-08-12 16:09:28,236 Parameters: domain_right_edge         = [1. 1. 1.] code_length
# yt : [INFO     ] 2025-08-12 16:09:28,236 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2025-08-12 16:09:28,297 Allocating for 180 particles
# /home/claire/miniforge3/envs/salsa-env/lib/python3.13/site-packages/unyt/array.py:1972: RuntimeWarning: invalid value encountered in divide
#   out_arr = func(
# yt : [INFO     ] 2025-08-12 16:09:29,067 Parameters: current_time              = 0.0060000200028298 code_time
# yt : [INFO     ] 2025-08-12 16:09:29,067 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-08-12 16:09:29,068 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2025-08-12 16:09:29,068 Parameters: domain_right_edge         = [1. 1. 1.] code_length
# yt : [INFO     ] 2025-08-12 16:09:29,069 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2025-08-12 16:09:29,125 Allocating for 249 particles
# yt : [INFO     ] 2025-08-12 16:09:29,348 Parameters: current_time              = 0.0060000200028298 code_time
# yt : [INFO     ] 2025-08-12 16:09:29,348 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-08-12 16:09:29,349 Parameters: domain_left_edge          = [0. 0. 0.] code_length
# yt : [INFO     ] 2025-08-12 16:09:29,349 Parameters: domain_right_edge         = [1. 1. 1.] code_length
# yt : [INFO     ] 2025-08-12 16:09:29,350 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2025-08-12 16:09:29,408 Allocating for 180 particles
# No absorbers in ray:  ray1.h5

# %%
tab
# Out:
# <QTable length=3>
# name   wave   redshift ...      metallicity      lightray_index
#      Angstrom          ...
# str4 float64  float64  ...        float64            int64
# ---- -------- -------- ... --------------------- --------------
#  H I  1215.67      0.0 ... 7.446666243321759e-05              0
#  H I  1215.67      0.0 ... 7.446666730115665e-05              1
# C IV 1548.187      0.0 ... 7.446666482203609e-05              0
