# %% [markdown]
# # begin analyzing cosmological sims in a similar manner as before.

# %%
import yt
import numpy as np
import trident
from IPython.display import Image

# %%
fname="/mnt/gs18/scratch/users/boydbre1/cosmological/RD0042/RD0042"

# %%
ds = yt.load(fname)

# %%
ds1 = yt.load("/mnt/gs18/scratch/users/boydbre1/cosmological/RD0036/RD0036")

# %% [markdown]
# # no plots

# %%
ds1.current_redshift
# Out:
# 0.29999997284034

# %%
tot_prj = yt.ProjectionPlot(ds, 'x', 'density', center='max')
tot_prj1 = yt.ProjectionPlot(ds1, 'x', 'density', center='max')
# Out:
# ...
# Parsing Hierarchy : 100%|██████████| 1731/1731 [00:00<00:00, 5617.82it/s]

# %%
maxHI= ds.find_max('HI_Density')
maxHI1= ds1.find_max('HI_Density')
print(maxHI)
print(maxHI1)
# Out:
# (2157103.6159974025 code_mass/code_length**3, YTArray([0.49926186, 0.45455742, 0.50519753]) code_length)
# (3636534.0409041736 code_mass/code_length**3, YTArray([0.49093819, 0.47535515, 0.50779152]) code_length)

# %%
tot_prj.annotate_marker(maxHI[1])
tot_prj1.annotate_marker(maxHI1[1])
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
tot_prj1.set_cmap('density', cmap='magma')
tot_prj.set_cmap('density', cmap='magma')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
tot_prj.zoom(1000)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
tot_prjy = yt.ProjectionPlot(ds, 'y', 'density', center='max')
tot_prjy.annotate_marker(maxHI[1])
tot_prjy.set_cmap('density', cmap='magma')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
tot_prjy.zoom(1000)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
tot_prj1.zoom(1000)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
tot_prj1.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2bf76b49a614> in <module>
# ----> 1 tot_prj1.save()
#
# NameError: name 'tot_prj1' is not defined

# %%
tot_prj1.set_cmap('density', cmap='magma')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
hprj1= yt.ProjectionPlot(ds1, 'x', 'H_p0_number_density', center='max')
hprj1.set_cmap("H_p0_number_density", cmap='magma')
hprj1.zoom(1000)
# Out:
# Parsing Hierarchy : 100%|██████████| 1731/1731 [00:00<00:00, 6515.94it/s]
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
hprjy= yt.ProjectionPlot(ds, 'y', 'H_p0_number_density', center='max')
hprjy.set_cmap("H_p0_number_density", cmap='magma')
hprjy.zoom(1000)
# Out:
# Parsing Hierarchy : 100%|██████████| 1817/1817 [00:00<00:00, 5664.15it/s]
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
hprjy.zoom(2)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.SlicePlot(ds1, 'x', 'H_p0_number_density', center=maxHI1[1])

# %%
slc.zoom(5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc.set_cmap()

# %%
slc.annotate_marker(maxHI1[1])
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc.zoom(0.25)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
mp = ds.quan(20, 'Mpc')
mp.in_units('code_length')
# Out:
# 0.13899999999999998 code_length

# %%
lc_prj = yt.ProjectionPlot(ds, 'x', 'Density', width = (50, 'Mpc'), center=(0.5, 0.13, 0.13))

# %%
lc_prj
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
tot_prj.zoom(1.5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
lc_slc = yt.SlicePlot(ds, 'x', 'Density', width = (50, 'Mpc'), center=(0.5, 0.13, 0.13))

# %%
lc_slc.zoom(4)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
